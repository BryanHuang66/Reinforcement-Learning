# %% [markdown]
# ## 提取迷宫

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import tkinter as tk
import sys
import time
import pandas as pd
from tqdm import tqdm

# %%
def check_pixel(block):
    if np.max(block) > 200:
        return 0
    else:
        return 1
def read_maze(img_name):
    bound_x_min = 50
    bound_x_max = 570
    bound_y_min = 48
    bound_y_max = 440
    img = cv2.imread(img_name)
    img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    step = 8
    maze = np.zeros(((bound_y_max-bound_y_min)//step, (bound_x_max-bound_x_min)//step))
    maze.shape
    for i in range(maze.shape[0]):
        for j in range(maze.shape[1]):
            maze[i,j] = check_pixel(img_gray[bound_y_min+i*step:bound_y_min+(i+1)*step, bound_x_min+j*step:bound_x_min+(j+1)*step])
    maze[-5,-2] = 1
    maze[-1,-2] = 0
    return maze
maze = read_maze('maze.jpeg')
plt.imshow(maze, cmap='gray')

# %% [markdown]
# ## Sarsa-learning算法

# %%
class Sarsa_learning_table():
    def __init__(self,
                 maze,
                 learning_rate=0.01,
                 exploration_decay=0.9):
        self.actions = list(range(4))
        self.maze = maze
        self.learning_rate = learning_rate
        self.exploration_decay = exploration_decay
        self.q_table = pd.DataFrame(columns=list(range(4)), dtype=np.float32)
        self.init_status()
    
    def init_status(self):
        path_index = np.where(maze == 1)
        path_index_list = []
        for i in range(len(path_index[0])):
            path_index_list.append((path_index[0][i],path_index[1][i]))
        for item in path_index_list:
            up = 0
            down = 0
            left = 0
            right = 0
            if (item[0]-1,item[1]) not in path_index_list:
                up = -1
            if (item[0]+1,item[1]) not in path_index_list:
                down = -1
            if (item[0],item[1]-1) not in path_index_list:
                left = -1
            if (item[0],item[1]+1) not in path_index_list:
                right = -1
            self.q_table.loc[str([item[1],item[0]])] = [up,down,right,left]
        block_index = np.where(maze == 0)
        for i in range(len(block_index[0])):
            self.q_table.loc[str([block_index[1][i],block_index[0][i]])] = [0,0,0,0]
    
    def choose_action(self, s, random):
        s = str(s)
        if np.random.uniform() < random:
            state_action = self.q_table.loc[s, :]
            state_action = state_action.reindex(
                np.random.permutation(
                    state_action.index))  # 防止相同列值时取第一个列，所以打乱列的顺序
            action = state_action.idxmax()
        else:
            action = np.random.choice(self.actions)
        return action
    
    def rl(self, s, a, r, s_,a_):
        q_predict = self.q_table.loc[s, a]  # q估计
        if s_ != 'terminal':
            q_target = r + self.exploration_decay * self.q_table.loc[
                s_, a_]  # q现实
        else:
            q_target = r
        self.q_table.loc[s, a] += self.learning_rate * (q_target - q_predict)

# %%
from copy import deepcopy
import pickle
class SimulateRun():
    def __init__(self, maze,RL, oval,iter=400, startpoint=[63,44],exploration_greedy=0.999):
        self.maze = maze
        self.oval = oval
        self.iter = iter
        self.startpoint = deepcopy(startpoint)
        self.visit_set = set()
        self.curpoint = deepcopy(startpoint)
        self.nextpoint = deepcopy(startpoint)
        self.RL = RL
        self.exploration_greedy = exploration_greedy
        self.init_status()
        
    def init_status(self):
        self.blocks = []
        block_index = np.where(self.maze == 0)
        for i in range(len(block_index[0])):
            self.blocks.append([block_index[1][i], block_index[0][i]])
    def step(self,action):
        if action == 0:
            self.nextpoint[1] = self.curpoint[1] - 1
        elif action == 1:
            self.nextpoint[1] = self.curpoint[1] + 1
        elif action == 2:
            self.nextpoint[0] = self.curpoint[0] + 1
        elif action == 3:
            self.nextpoint[0] = self.curpoint[0] - 1
        if self.nextpoint in self.blocks:
            self.visit_set = set()
            return -1,True
        elif self.curpoint == self.oval:
            # print('success')
            self.visit_set = set()
            return 1,True
        elif str(self.nextpoint) in self.visit_set:
            self.visit_set.add(str(self.nextpoint))
            return -0.1,False
        else:
            self.visit_set.add(str(self.nextpoint))
            return 0,False
    def run(self):
        for i in tqdm(range(self.iter)):
            action_cur = self.RL.choose_action(self.curpoint,self.exploration_greedy)
            while True:
                reward,condition = self.step(action_cur)
                action_next = self.RL.choose_action(self.nextpoint,self.exploration_greedy)
                # print(action_next)
                self.RL.rl(str(self.curpoint), action_cur, reward, str(self.nextpoint), action_next)
                self.curpoint = deepcopy(self.nextpoint)
                action_cur = deepcopy(action_next)
                if condition:
                    self.curpoint = deepcopy(self.startpoint)
                    self.nextpoint = deepcopy(self.startpoint)
                    break

# %%
# oval = [1,1]
# startpoint = [63,44]
# RL = Sarsa_learning_table(maze=maze)
# SR =  SimulateRun(maze,RL,oval)
# SR.run()
# with open(f'sarsa_learning_table-{startpoint}-{oval}.pkl', 'wb') as pkl_file:
#     pickle.dump(SR, pkl_file)

# %% [markdown]
# ## 预测

# %%
def predict_by_file(file,startpoint,oval):
    with open(file, 'rb') as pkl_file:
        SR = pickle.load(pkl_file)
    print('start_state:{}'.format(startpoint))
    SR.curpoint = deepcopy(startpoint)
    step = 0
    path = []
    action_cur = SR.RL.choose_action(SR.curpoint, 1)
    while True:
            step = step + 1
            # action = SR.RL.choose_action(SR.curpoint, 1)
            # 预测阶段，reward用不到了，故使用_代替
            _, condition = SR.step(action_cur)
            action_next = SR.RL.choose_action(SR.nextpoint, 1)
            # SR.RL.rl(str(SR.curpoint), action_cur, 0, str(SR.nextpoint),action_next)
            # 输出动作和下个状态
            print('step:{step}, action: {action}, state: {state}'.format(step=step, action=action_cur, state=SR.curpoint))
            record_point = deepcopy(SR.curpoint)
            record_point.append(action_cur)
            path.append(record_point)

            # 如果done或者步数超过100,游戏结束退出
            if condition or step > 1000:
                if SR.curpoint == oval:
                    print('success')
                else:
                    print('fail')
                break
            # 跳转到下个状态
            else:
                SR.curpoint = deepcopy(SR.nextpoint)
                action_cur = deepcopy(action_next)
    return path

# %% [markdown]
# ## 交互

# %%
class MazeConstructor(tk.Tk):
    def __init__(self,maze,oval,path,startpoint=[63,44],MAZE_H=49,MAZE_W=65,UNIT=16):
        super(MazeConstructor, self).__init__()
        self.UNIT = UNIT
        self.MAZE_H = MAZE_H
        self.MAZE_W = MAZE_W
        self.maze = maze
        self.oval = oval
        self.path = path
        self.startpoint = startpoint
        self.visit_set = set(str(self.startpoint))
        self.geometry('{0}x{1}'.format(self.MAZE_H * self.UNIT,
                                       self.MAZE_W * self.UNIT))
        self.tk_build_maze()

    def tk_draw_square(self,x,y,c):
        center = self.UNIT / 2
        w = center - 5
        x_ = self.UNIT * x + center
        y_ = self.UNIT * y + center
        return self.canvas.create_rectangle(x_ - w, y_ - w, x_ + w, y_ + w, fill=c)
    
    def tk_create_line(self,x,y,direction,c):
        center = self.UNIT / 2
        w = center - 5 
        if direction == 1: # up
            x1 = x * self.UNIT + center
            y1 = y * self.UNIT + center -w
            x2 = x * self.UNIT + center
            y2 = y * self.UNIT + center + w
        if direction == 0: # down
            x1 = x * self.UNIT + center 
            y1 = y * self.UNIT + center + w
            x2 = x * self.UNIT + center  
            y2 = y * self.UNIT + center - w
        if direction == 2: # left
            x1 = x * self.UNIT + center - w
            y1 = y * self.UNIT + center
            x2 = x * self.UNIT + center + w
            y2 = y * self.UNIT + center
        if direction == 3: # right
            x1 = x * self.UNIT + center + w
            y1 = y * self.UNIT + center
            x2 = x * self.UNIT + center - w
            y2 = y * self.UNIT + center
        return self.canvas.create_line(x1,y1,x2,y2,width=2,arrow=tk.LAST,fill=c)


    def tk_build_maze(self):
        h = self.MAZE_H * self.UNIT
        w = self.MAZE_W * self.UNIT
        # 初始化画布
        self.canvas = tk.Canvas(self, bg='white', height=h, width=w)
        # 画线
        for c in range(0, w, self.UNIT):
            self.canvas.create_line(c, 0, c, h)
        for r in range(0, h, self.UNIT):
            self.canvas.create_line(0, r, w, r)

        # 陷阱
        self.hells = []
        block_index = np.where(self.maze == 0)
        for i in range(len(block_index[0])):
            self.hells.append(self.tk_draw_square(block_index[1][i], block_index[0][i], 'black'))
        self.hell_coords = []
        for hell in self.hells:
            self.hell_coords.append(self.canvas.coords(hell))
        
        # 奖励
        if self.oval!=[]:
            self.oval = self.tk_draw_square(*self.oval, 'red')

        # 路径
        self.path = [self.tk_create_line(*p, 'orange') for p in self.path]
        # 玩家对象
        self.rect = self.tk_draw_square( *self.startpoint, 'yellow')

        self.canvas.pack()  #执行画
    
    def reset(self,oval,path,startpoint=[63,44]):
        self.canvas.delete("all")
        self.oval = oval
        self.path = path
        self.startpoint = startpoint
        h = self.MAZE_H * self.UNIT
        w = self.MAZE_W * self.UNIT
        # 初始化画布
        # self.canvas = tk.Canvas(self, bg='white', height=h, width=w)
        # 画线
        for c in range(0, w, self.UNIT):
            self.canvas.create_line(c, 0, c, h)
        for r in range(0, h, self.UNIT):
            self.canvas.create_line(0, r, w, r)
        self.hells = []
        block_index = np.where(self.maze == 0)
        for i in range(len(block_index[0])):
            self.hells.append(self.tk_draw_square(block_index[1][i], block_index[0][i], 'black'))
        self.hell_coords = []
        for hell in self.hells:
            self.hell_coords.append(self.canvas.coords(hell))
        # 路径
        self.path = [self.tk_create_line(*p, 'orange') for p in self.path]
        # 奖励
        self.oval = self.tk_draw_square(*self.oval, 'red')
        self.rect = self.tk_draw_square( *self.startpoint, 'yellow')
        self.update()

# %%
def callback(event):
    # print( "clicked at:", event.x, event.y)#打印出该事件（按下鼠标）的x，y轴
    oval = [event.x//16,event.y//16]
    if 0<=oval[0]<65 and 0<=oval[1]<49 and oval not in block_list:
        env.reset(oval,[]) 
        print(oval)
        startpoint = [63,44]
        RL = Sarsa_learning_table(maze=maze)
        SR =  SimulateRun(maze,RL,oval)
        SR.run()
        with open(f'q_learning_table-{startpoint}-{oval}.pkl', 'wb') as pkl_file:
            pickle.dump(SR, pkl_file)
        path = predict_by_file(f'q_learning_table-{startpoint}-{oval}.pkl',startpoint,oval)
        env.reset(oval,path[1:-1])
    
env = MazeConstructor(maze,[],[])
block = np.where(maze==0)
block_list = []
for i in range(len(block[0])):
    block_list.append([block[1][i],block[0][i]])
env.bind("<Button-1>", callback)
env.mainloop()
# Out:
# [47, 35]
# 100%|██████████| 400/400 [09:42<00:00,  1.46s/it]
# start_state:[63, 44]
# step:1, action: 0, state: [63, 44]
# step:2, action: 0, state: [63, 43]
# step:3, action: 0, state: [63, 42]
# step:4, action: 0, state: [63, 41]
# step:5, action: 0, state: [63, 40]
# step:6, action: 0, state: [63, 39]
# step:7, action: 0, state: [63, 38]
# step:8, action: 0, state: [63, 37]
# step:9, action: 0, state: [63, 36]
# step:10, action: 0, state: [63, 35]
# step:11, action: 0, state: [63, 34]
# step:12, action: 0, state: [63, 33]
# step:13, action: 0, state: [63, 32]
# step:14, action: 0, state: [63, 31]
# step:15, action: 0, state: [63, 30]
# step:16, action: 0, state: [63, 29]
# step:17, action: 0, state: [63, 28]
# step:18, action: 3, state: [63, 27]
# step:19, action: 3, state: [62, 27]
# step:20, action: 1, state: [61, 27]
# step:21, action: 1, state: [61, 28]
# step:22, action: 1, state: [61, 29]
# step:23, action: 1, state: [61, 30]
# step:24, action: 3, state: [61, 31]
# step:25, action: 3, state: [60, 31]
# step:26, action: 3, state: [59, 31]
# step:27, action: 3, state: [58, 31]
# step:28, action: 0, state: [57, 31]
# step:29, action: 0, state: [57, 30]
# step:30, action: 0, state: [57, 29]
# step:31, action: 0, state: [57, 28]
# step:32, action: 0, state: [57, 27]
# step:33, action: 0, state: [57, 26]
# step:34, action: 3, state: [57, 25]
# step:35, action: 3, state: [56, 25]
# step:36, action: 1, state: [55, 25]
# step:37, action: 1, state: [55, 26]
# step:38, action: 1, state: [55, 27]
# step:39, action: 1, state: [55, 28]
# step:40, action: 3, state: [55, 29]
# step:41, action: 3, state: [54, 29]
# step:42, action: 1, state: [53, 29]
# step:43, action: 1, state: [53, 30]
# step:44, action: 3, state: [53, 31]
# step:45, action: 3, state: [52, 31]
# step:46, action: 0, state: [51, 31]
# step:47, action: 0, state: [51, 30]
# step:48, action: 3, state: [51, 29]
# step:49, action: 3, state: [50, 29]
# step:50, action: 0, state: [49, 29]
# step:51, action: 0, state: [49, 28]
# step:52, action: 0, state: [49, 27]
# step:53, action: 0, state: [49, 26]
# step:54, action: 0, state: [49, 25]
# step:55, action: 0, state: [49, 24]
# step:56, action: 3, state: [49, 23]
# step:57, action: 3, state: [48, 23]
# step:58, action: 0, state: [47, 23]
# step:59, action: 0, state: [47, 22]
# step:60, action: 0, state: [47, 21]
# step:61, action: 0, state: [47, 20]
# step:62, action: 0, state: [47, 19]
# step:63, action: 0, state: [47, 18]
# step:64, action: 2, state: [47, 17]
# step:65, action: 2, state: [48, 17]
# step:66, action: 1, state: [49, 17]
# step:67, action: 1, state: [49, 18]
# step:68, action: 1, state: [49, 19]
# step:69, action: 1, state: [49, 20]
# step:70, action: 2, state: [49, 21]
# step:71, action: 2, state: [50, 21]
# step:72, action: 2, state: [51, 21]
# step:73, action: 2, state: [52, 21]
# step:74, action: 1, state: [53, 21]
# step:75, action: 1, state: [53, 22]
# step:76, action: 2, state: [53, 23]
# step:77, action: 2, state: [54, 23]
# step:78, action: 2, state: [55, 23]
# step:79, action: 2, state: [56, 23]
# step:80, action: 0, state: [57, 23]
# step:81, action: 0, state: [57, 22]
# step:82, action: 3, state: [57, 21]
# step:83, action: 3, state: [56, 21]
# step:84, action: 0, state: [55, 21]
# step:85, action: 0, state: [55, 20]
# step:86, action: 0, state: [55, 19]
# step:87, action: 0, state: [55, 18]
# step:88, action: 0, state: [55, 17]
# step:89, action: 0, state: [55, 16]
# step:90, action: 0, state: [55, 15]
# step:91, action: 0, state: [55, 14]
# step:92, action: 0, state: [55, 13]
# step:93, action: 0, state: [55, 12]
# step:94, action: 3, state: [55, 11]
# step:95, action: 3, state: [54, 11]
# step:96, action: 3, state: [53, 11]
# step:97, action: 3, state: [52, 11]
# step:98, action: 1, state: [51, 11]
# step:99, action: 1, state: [51, 12]
# step:100, action: 1, state: [51, 13]
# step:101, action: 1, state: [51, 14]
# step:102, action: 3, state: [51, 15]
# step:103, action: 3, state: [50, 15]
# step:104, action: 0, state: [49, 15]
# step:105, action: 0, state: [49, 14]
# step:106, action: 0, state: [49, 13]
# step:107, action: 0, state: [49, 12]
# step:108, action: 0, state: [49, 11]
# step:109, action: 0, state: [49, 10]
# step:110, action: 0, state: [49, 9]
# step:111, action: 0, state: [49, 8]
# step:112, action: 0, state: [49, 7]
# step:113, action: 0, state: [49, 6]
# step:114, action: 3, state: [49, 5]
# step:115, action: 3, state: [48, 5]
# step:116, action: 1, state: [47, 5]
# step:117, action: 1, state: [47, 6]
# step:118, action: 3, state: [47, 7]
# step:119, action: 3, state: [46, 7]
# step:120, action: 1, state: [45, 7]
# step:121, action: 1, state: [45, 8]
# step:122, action: 1, state: [45, 9]
# step:123, action: 1, state: [45, 10]
# step:124, action: 3, state: [45, 11]
# step:125, action: 3, state: [44, 11]
# step:126, action: 0, state: [43, 11]
# step:127, action: 0, state: [43, 10]
# step:128, action: 0, state: [43, 9]
# step:129, action: 0, state: [43, 8]
# step:130, action: 0, state: [43, 7]
# step:131, action: 0, state: [43, 6]
# step:132, action: 3, state: [43, 5]
# step:133, action: 3, state: [42, 5]
# step:134, action: 0, state: [41, 5]
# step:135, action: 0, state: [41, 4]
# step:136, action: 2, state: [41, 3]
# step:137, action: 2, state: [42, 3]
# step:138, action: 0, state: [43, 3]
# step:139, action: 0, state: [43, 2]
# step:140, action: 2, state: [43, 1]
# step:141, action: 2, state: [44, 1]
# step:142, action: 1, state: [45, 1]
# step:143, action: 1, state: [45, 2]
# step:144, action: 2, state: [45, 3]
# step:145, action: 2, state: [46, 3]
# step:146, action: 0, state: [47, 3]
# step:147, action: 0, state: [47, 2]
# step:148, action: 2, state: [47, 1]
# step:149, action: 2, state: [48, 1]
# step:150, action: 2, state: [49, 1]
# step:151, action: 2, state: [50, 1]
# step:152, action: 1, state: [51, 1]
# step:153, action: 1, state: [51, 2]
# step:154, action: 1, state: [51, 3]
# step:155, action: 1, state: [51, 4]
# step:156, action: 1, state: [51, 5]
# step:157, action: 1, state: [51, 6]
# step:158, action: 2, state: [51, 7]
# step:159, action: 2, state: [52, 7]
# step:160, action: 2, state: [53, 7]
# step:161, action: 2, state: [54, 7]
# step:162, action: 2, state: [55, 7]
# step:163, action: 2, state: [56, 7]
# step:164, action: 1, state: [57, 7]
# step:165, action: 1, state: [57, 8]
# step:166, action: 2, state: [57, 9]
# step:167, action: 2, state: [58, 9]
# step:168, action: 2, state: [59, 9]
# step:169, action: 2, state: [60, 9]
# step:170, action: 2, state: [61, 9]
# step:171, action: 2, state: [62, 9]
# step:172, action: 1, state: [63, 9]
# step:173, action: 1, state: [63, 10]
# step:174, action: 3, state: [63, 11]
# step:175, action: 3, state: [62, 11]
# step:176, action: 1, state: [61, 11]
# step:177, action: 1, state: [61, 12]
# step:178, action: 3, state: [61, 13]
# step:179, action: 3, state: [60, 13]
# step:180, action: 3, state: [59, 13]
# step:181, action: 3, state: [58, 13]
# step:182, action: 1, state: [57, 13]
# step:183, action: 1, state: [57, 14]
# step:184, action: 1, state: [57, 15]
# step:185, action: 1, state: [57, 16]
# step:186, action: 2, state: [57, 17]
# step:187, action: 2, state: [58, 17]
# step:188, action: 2, state: [59, 17]
# step:189, action: 2, state: [60, 17]
# step:190, action: 1, state: [61, 17]
# step:191, action: 1, state: [61, 18]
# step:192, action: 3, state: [61, 19]
# step:193, action: 3, state: [60, 19]
# step:194, action: 1, state: [59, 19]
# step:195, action: 1, state: [59, 20]
# step:196, action: 1, state: [59, 21]
# step:197, action: 0, state: [59, 22]
# step:198, action: 1, state: [59, 21]
# step:199, action: 0, state: [59, 22]
# step:200, action: 1, state: [59, 21]
# step:201, action: 0, state: [59, 22]
# step:202, action: 1, state: [59, 21]
# step:203, action: 0, state: [59, 22]
# step:204, action: 1, state: [59, 21]
# step:205, action: 0, state: [59, 22]
# step:206, action: 1, state: [59, 21]
# step:207, action: 0, state: [59, 22]
# step:208, action: 1, state: [59, 21]
# step:209, action: 0, state: [59, 22]
# step:210, action: 1, state: [59, 21]
# step:211, action: 0, state: [59, 22]
# step:212, action: 1, state: [59, 21]
# step:213, action: 0, state: [59, 22]
# step:214, action: 1, state: [59, 21]
# step:215, action: 0, state: [59, 22]
# step:216, action: 1, state: [59, 21]
# step:217, action: 0, state: [59, 22]
# step:218, action: 1, state: [59, 21]
# step:219, action: 0, state: [59, 22]
# step:220, action: 1, state: [59, 21]
# step:221, action: 0, state: [59, 22]
# step:222, action: 1, state: [59, 21]
# step:223, action: 0, state: [59, 22]
# step:224, action: 1, state: [59, 21]
# step:225, action: 0, state: [59, 22]
# step:226, action: 1, state: [59, 21]
# step:227, action: 0, state: [59, 22]
# step:228, action: 1, state: [59, 21]
# step:229, action: 0, state: [59, 22]
# step:230, action: 1, state: [59, 21]
# step:231, action: 0, state: [59, 22]
# step:232, action: 1, state: [59, 21]
# step:233, action: 0, state: [59, 22]
# step:234, action: 1, state: [59, 21]
# step:235, action: 0, state: [59, 22]
# step:236, action: 1, state: [59, 21]
# step:237, action: 0, state: [59, 22]
# step:238, action: 1, state: [59, 21]
# step:239, action: 0, state: [59, 22]
# step:240, action: 1, state: [59, 21]
# step:241, action: 0, state: [59, 22]
# step:242, action: 1, state: [59, 21]
# step:243, action: 0, state: [59, 22]
# step:244, action: 1, state: [59, 21]
# step:245, action: 0, state: [59, 22]
# step:246, action: 1, state: [59, 21]
# step:247, action: 0, state: [59, 22]
# step:248, action: 1, state: [59, 21]
# step:249, action: 0, state: [59, 22]
# step:250, action: 1, state: [59, 21]
# step:251, action: 0, state: [59, 22]
# step:252, action: 1, state: [59, 21]
# step:253, action: 0, state: [59, 22]
# step:254, action: 1, state: [59, 21]
# step:255, action: 0, state: [59, 22]
# step:256, action: 1, state: [59, 21]
# step:257, action: 0, state: [59, 22]
# step:258, action: 1, state: [59, 21]
# step:259, action: 0, state: [59, 22]
# step:260, action: 1, state: [59, 21]
# step:261, action: 0, state: [59, 22]
# step:262, action: 1, state: [59, 21]
# step:263, action: 0, state: [59, 22]
# step:264, action: 1, state: [59, 21]
# step:265, action: 0, state: [59, 22]
# step:266, action: 1, state: [59, 21]
# step:267, action: 0, state: [59, 22]
# step:268, action: 1, state: [59, 21]
# step:269, action: 0, state: [59, 22]
# step:270, action: 1, state: [59, 21]
# step:271, action: 0, state: [59, 22]
# step:272, action: 1, state: [59, 21]
# step:273, action: 0, state: [59, 22]
# step:274, action: 1, state: [59, 21]
# step:275, action: 0, state: [59, 22]
# step:276, action: 1, state: [59, 21]
# step:277, action: 0, state: [59, 22]
# step:278, action: 1, state: [59, 21]
# step:279, action: 0, state: [59, 22]
# step:280, action: 1, state: [59, 21]
# step:281, action: 0, state: [59, 22]
# step:282, action: 1, state: [59, 21]
# step:283, action: 0, state: [59, 22]
# step:284, action: 1, state: [59, 21]
# step:285, action: 0, state: [59, 22]
# step:286, action: 1, state: [59, 21]
# step:287, action: 0, state: [59, 22]
# step:288, action: 1, state: [59, 21]
# step:289, action: 0, state: [59, 22]
# step:290, action: 1, state: [59, 21]
# step:291, action: 0, state: [59, 22]
# step:292, action: 1, state: [59, 21]
# step:293, action: 0, state: [59, 22]
# step:294, action: 1, state: [59, 21]
# step:295, action: 0, state: [59, 22]
# step:296, action: 1, state: [59, 21]
# step:297, action: 0, state: [59, 22]
# step:298, action: 1, state: [59, 21]
# step:299, action: 0, state: [59, 22]
# step:300, action: 1, state: [59, 21]
# step:301, action: 0, state: [59, 22]
# step:302, action: 1, state: [59, 21]
# step:303, action: 0, state: [59, 22]
# step:304, action: 1, state: [59, 21]
# step:305, action: 0, state: [59, 22]
# step:306, action: 1, state: [59, 21]
# step:307, action: 0, state: [59, 22]
# step:308, action: 1, state: [59, 21]
# step:309, action: 0, state: [59, 22]
# step:310, action: 1, state: [59, 21]
# step:311, action: 0, state: [59, 22]
# step:312, action: 1, state: [59, 21]
# step:313, action: 0, state: [59, 22]
# step:314, action: 1, state: [59, 21]
# step:315, action: 0, state: [59, 22]
# step:316, action: 1, state: [59, 21]
# step:317, action: 0, state: [59, 22]
# step:318, action: 1, state: [59, 21]
# step:319, action: 0, state: [59, 22]
# step:320, action: 1, state: [59, 21]
# step:321, action: 0, state: [59, 22]
# step:322, action: 1, state: [59, 21]
# step:323, action: 0, state: [59, 22]
# step:324, action: 1, state: [59, 21]
# step:325, action: 0, state: [59, 22]
# step:326, action: 1, state: [59, 21]
# step:327, action: 0, state: [59, 22]
# step:328, action: 1, state: [59, 21]
# step:329, action: 0, state: [59, 22]
# step:330, action: 1, state: [59, 21]
# step:331, action: 0, state: [59, 22]
# step:332, action: 1, state: [59, 21]
# step:333, action: 0, state: [59, 22]
# step:334, action: 1, state: [59, 21]
# step:335, action: 0, state: [59, 22]
# step:336, action: 1, state: [59, 21]
# step:337, action: 0, state: [59, 22]
# step:338, action: 1, state: [59, 21]
# step:339, action: 0, state: [59, 22]
# step:340, action: 1, state: [59, 21]
# step:341, action: 0, state: [59, 22]
# step:342, action: 1, state: [59, 21]
# step:343, action: 0, state: [59, 22]
# step:344, action: 1, state: [59, 21]
# step:345, action: 0, state: [59, 22]
# step:346, action: 1, state: [59, 21]
# step:347, action: 0, state: [59, 22]
# step:348, action: 1, state: [59, 21]
# step:349, action: 0, state: [59, 22]
# step:350, action: 1, state: [59, 21]
# step:351, action: 0, state: [59, 22]
# step:352, action: 1, state: [59, 21]
# step:353, action: 0, state: [59, 22]
# step:354, action: 1, state: [59, 21]
# step:355, action: 0, state: [59, 22]
# step:356, action: 1, state: [59, 21]
# step:357, action: 0, state: [59, 22]
# step:358, action: 1, state: [59, 21]
# step:359, action: 0, state: [59, 22]
# step:360, action: 1, state: [59, 21]
# step:361, action: 0, state: [59, 22]
# step:362, action: 1, state: [59, 21]
# step:363, action: 0, state: [59, 22]
# step:364, action: 1, state: [59, 21]
# step:365, action: 0, state: [59, 22]
# step:366, action: 1, state: [59, 21]
# step:367, action: 0, state: [59, 22]
# step:368, action: 1, state: [59, 21]
# step:369, action: 0, state: [59, 22]
# step:370, action: 1, state: [59, 21]
# step:371, action: 0, state: [59, 22]
# step:372, action: 1, state: [59, 21]
# step:373, action: 0, state: [59, 22]
# step:374, action: 1, state: [59, 21]
# step:375, action: 0, state: [59, 22]
# step:376, action: 1, state: [59, 21]
# step:377, action: 0, state: [59, 22]
# step:378, action: 1, state: [59, 21]
# step:379, action: 0, state: [59, 22]
# step:380, action: 1, state: [59, 21]
# step:381, action: 0, state: [59, 22]
# step:382, action: 1, state: [59, 21]
# step:383, action: 0, state: [59, 22]
# step:384, action: 1, state: [59, 21]
# step:385, action: 0, state: [59, 22]
# step:386, action: 1, state: [59, 21]
# step:387, action: 0, state: [59, 22]
# step:388, action: 1, state: [59, 21]
# step:389, action: 0, state: [59, 22]
# step:390, action: 1, state: [59, 21]
# step:391, action: 0, state: [59, 22]
# step:392, action: 1, state: [59, 21]
# step:393, action: 0, state: [59, 22]
# step:394, action: 1, state: [59, 21]
# step:395, action: 0, state: [59, 22]
# step:396, action: 1, state: [59, 21]
# step:397, action: 0, state: [59, 22]
# step:398, action: 1, state: [59, 21]
# step:399, action: 0, state: [59, 22]
# step:400, action: 1, state: [59, 21]
# step:401, action: 0, state: [59, 22]
# step:402, action: 1, state: [59, 21]
# step:403, action: 0, state: [59, 22]
# step:404, action: 1, state: [59, 21]
# step:405, action: 0, state: [59, 22]
# step:406, action: 1, state: [59, 21]
# step:407, action: 0, state: [59, 22]
# step:408, action: 1, state: [59, 21]
# step:409, action: 0, state: [59, 22]
# step:410, action: 1, state: [59, 21]
# step:411, action: 0, state: [59, 22]
# step:412, action: 1, state: [59, 21]
# step:413, action: 0, state: [59, 22]
# step:414, action: 1, state: [59, 21]
# step:415, action: 0, state: [59, 22]
# step:416, action: 1, state: [59, 21]
# step:417, action: 0, state: [59, 22]
# step:418, action: 1, state: [59, 21]
# step:419, action: 0, state: [59, 22]
# step:420, action: 1, state: [59, 21]
# step:421, action: 0, state: [59, 22]
# step:422, action: 1, state: [59, 21]
# step:423, action: 0, state: [59, 22]
# step:424, action: 1, state: [59, 21]
# step:425, action: 0, state: [59, 22]
# step:426, action: 1, state: [59, 21]
# step:427, action: 0, state: [59, 22]
# step:428, action: 1, state: [59, 21]
# step:429, action: 0, state: [59, 22]
# step:430, action: 1, state: [59, 21]
# step:431, action: 0, state: [59, 22]
# step:432, action: 1, state: [59, 21]
# step:433, action: 0, state: [59, 22]
# step:434, action: 1, state: [59, 21]
# step:435, action: 0, state: [59, 22]
# step:436, action: 1, state: [59, 21]
# step:437, action: 0, state: [59, 22]
# step:438, action: 1, state: [59, 21]
# step:439, action: 0, state: [59, 22]
# step:440, action: 1, state: [59, 21]
# step:441, action: 0, state: [59, 22]
# step:442, action: 1, state: [59, 21]
# step:443, action: 0, state: [59, 22]
# step:444, action: 1, state: [59, 21]
# step:445, action: 0, state: [59, 22]
# step:446, action: 1, state: [59, 21]
# step:447, action: 0, state: [59, 22]
# step:448, action: 1, state: [59, 21]
# step:449, action: 0, state: [59, 22]
# step:450, action: 1, state: [59, 21]
# step:451, action: 0, state: [59, 22]
# step:452, action: 1, state: [59, 21]
# step:453, action: 0, state: [59, 22]
# step:454, action: 1, state: [59, 21]
# step:455, action: 0, state: [59, 22]
# step:456, action: 1, state: [59, 21]
# step:457, action: 0, state: [59, 22]
# step:458, action: 1, state: [59, 21]
# step:459, action: 0, state: [59, 22]
# step:460, action: 1, state: [59, 21]
# step:461, action: 0, state: [59, 22]
# step:462, action: 1, state: [59, 21]
# step:463, action: 0, state: [59, 22]
# step:464, action: 1, state: [59, 21]
# step:465, action: 0, state: [59, 22]
# step:466, action: 1, state: [59, 21]
# step:467, action: 0, state: [59, 22]
# step:468, action: 1, state: [59, 21]
# step:469, action: 0, state: [59, 22]
# step:470, action: 1, state: [59, 21]
# step:471, action: 0, state: [59, 22]
# step:472, action: 1, state: [59, 21]
# step:473, action: 0, state: [59, 22]
# step:474, action: 1, state: [59, 21]
# step:475, action: 0, state: [59, 22]
# step:476, action: 1, state: [59, 21]
# step:477, action: 0, state: [59, 22]
# step:478, action: 1, state: [59, 21]
# step:479, action: 0, state: [59, 22]
# step:480, action: 1, state: [59, 21]
# step:481, action: 0, state: [59, 22]
# step:482, action: 1, state: [59, 21]
# step:483, action: 0, state: [59, 22]
# step:484, action: 1, state: [59, 21]
# step:485, action: 0, state: [59, 22]
# step:486, action: 1, state: [59, 21]
# step:487, action: 0, state: [59, 22]
# step:488, action: 1, state: [59, 21]
# step:489, action: 0, state: [59, 22]
# step:490, action: 1, state: [59, 21]
# step:491, action: 0, state: [59, 22]
# step:492, action: 1, state: [59, 21]
# step:493, action: 0, state: [59, 22]
# step:494, action: 1, state: [59, 21]
# step:495, action: 0, state: [59, 22]
# step:496, action: 1, state: [59, 21]
# step:497, action: 0, state: [59, 22]
# step:498, action: 1, state: [59, 21]
# step:499, action: 0, state: [59, 22]
# step:500, action: 1, state: [59, 21]
# step:501, action: 0, state: [59, 22]
# step:502, action: 1, state: [59, 21]
# step:503, action: 0, state: [59, 22]
# step:504, action: 1, state: [59, 21]
# step:505, action: 0, state: [59, 22]
# step:506, action: 1, state: [59, 21]
# step:507, action: 0, state: [59, 22]
# step:508, action: 1, state: [59, 21]
# step:509, action: 0, state: [59, 22]
# step:510, action: 1, state: [59, 21]
# step:511, action: 0, state: [59, 22]
# step:512, action: 1, state: [59, 21]
# step:513, action: 0, state: [59, 22]
# step:514, action: 1, state: [59, 21]
# step:515, action: 0, state: [59, 22]
# step:516, action: 1, state: [59, 21]
# step:517, action: 0, state: [59, 22]
# step:518, action: 1, state: [59, 21]
# step:519, action: 0, state: [59, 22]
# step:520, action: 1, state: [59, 21]
# step:521, action: 0, state: [59, 22]
# step:522, action: 1, state: [59, 21]
# step:523, action: 0, state: [59, 22]
# step:524, action: 1, state: [59, 21]
# step:525, action: 0, state: [59, 22]
# step:526, action: 1, state: [59, 21]
# step:527, action: 0, state: [59, 22]
# step:528, action: 1, state: [59, 21]
# step:529, action: 0, state: [59, 22]
# step:530, action: 1, state: [59, 21]
# step:531, action: 0, state: [59, 22]
# step:532, action: 1, state: [59, 21]
# step:533, action: 0, state: [59, 22]
# step:534, action: 1, state: [59, 21]
# step:535, action: 0, state: [59, 22]
# step:536, action: 1, state: [59, 21]
# step:537, action: 0, state: [59, 22]
# step:538, action: 1, state: [59, 21]
# step:539, action: 0, state: [59, 22]
# step:540, action: 1, state: [59, 21]
# step:541, action: 0, state: [59, 22]
# step:542, action: 1, state: [59, 21]
# step:543, action: 0, state: [59, 22]
# step:544, action: 1, state: [59, 21]
# step:545, action: 0, state: [59, 22]
# step:546, action: 1, state: [59, 21]
# step:547, action: 0, state: [59, 22]
# step:548, action: 1, state: [59, 21]
# step:549, action: 0, state: [59, 22]
# step:550, action: 1, state: [59, 21]
# step:551, action: 0, state: [59, 22]
# step:552, action: 1, state: [59, 21]
# step:553, action: 0, state: [59, 22]
# step:554, action: 1, state: [59, 21]
# step:555, action: 0, state: [59, 22]
# step:556, action: 1, state: [59, 21]
# step:557, action: 0, state: [59, 22]
# step:558, action: 1, state: [59, 21]
# step:559, action: 0, state: [59, 22]
# step:560, action: 1, state: [59, 21]
# step:561, action: 0, state: [59, 22]
# step:562, action: 1, state: [59, 21]
# step:563, action: 0, state: [59, 22]
# step:564, action: 1, state: [59, 21]
# step:565, action: 0, state: [59, 22]
# step:566, action: 1, state: [59, 21]
# step:567, action: 0, state: [59, 22]
# step:568, action: 1, state: [59, 21]
# step:569, action: 0, state: [59, 22]
# step:570, action: 1, state: [59, 21]
# step:571, action: 0, state: [59, 22]
# step:572, action: 1, state: [59, 21]
# step:573, action: 0, state: [59, 22]
# step:574, action: 1, state: [59, 21]
# step:575, action: 0, state: [59, 22]
# step:576, action: 1, state: [59, 21]
# step:577, action: 0, state: [59, 22]
# step:578, action: 1, state: [59, 21]
# step:579, action: 0, state: [59, 22]
# step:580, action: 1, state: [59, 21]
# step:581, action: 0, state: [59, 22]
# step:582, action: 1, state: [59, 21]
# step:583, action: 0, state: [59, 22]
# step:584, action: 1, state: [59, 21]
# step:585, action: 0, state: [59, 22]
# step:586, action: 1, state: [59, 21]
# step:587, action: 0, state: [59, 22]
# step:588, action: 1, state: [59, 21]
# step:589, action: 0, state: [59, 22]
# step:590, action: 1, state: [59, 21]
# step:591, action: 0, state: [59, 22]
# step:592, action: 1, state: [59, 21]
# step:593, action: 0, state: [59, 22]
# step:594, action: 1, state: [59, 21]
# step:595, action: 0, state: [59, 22]
# step:596, action: 1, state: [59, 21]
# step:597, action: 0, state: [59, 22]
# step:598, action: 1, state: [59, 21]
# step:599, action: 0, state: [59, 22]
# step:600, action: 1, state: [59, 21]
# step:601, action: 0, state: [59, 22]
# step:602, action: 1, state: [59, 21]
# step:603, action: 0, state: [59, 22]
# step:604, action: 1, state: [59, 21]
# step:605, action: 0, state: [59, 22]
# step:606, action: 1, state: [59, 21]
# step:607, action: 0, state: [59, 22]
# step:608, action: 1, state: [59, 21]
# step:609, action: 0, state: [59, 22]
# step:610, action: 1, state: [59, 21]
# step:611, action: 0, state: [59, 22]
# step:612, action: 1, state: [59, 21]
# step:613, action: 0, state: [59, 22]
# step:614, action: 1, state: [59, 21]
# step:615, action: 0, state: [59, 22]
# step:616, action: 1, state: [59, 21]
# step:617, action: 0, state: [59, 22]
# step:618, action: 1, state: [59, 21]
# step:619, action: 0, state: [59, 22]
# step:620, action: 1, state: [59, 21]
# step:621, action: 0, state: [59, 22]
# step:622, action: 1, state: [59, 21]
# step:623, action: 0, state: [59, 22]
# step:624, action: 1, state: [59, 21]
# step:625, action: 0, state: [59, 22]
# step:626, action: 1, state: [59, 21]
# step:627, action: 0, state: [59, 22]
# step:628, action: 1, state: [59, 21]
# step:629, action: 0, state: [59, 22]
# step:630, action: 1, state: [59, 21]
# step:631, action: 0, state: [59, 22]
# step:632, action: 1, state: [59, 21]
# step:633, action: 0, state: [59, 22]
# step:634, action: 1, state: [59, 21]
# step:635, action: 0, state: [59, 22]
# step:636, action: 1, state: [59, 21]
# step:637, action: 0, state: [59, 22]
# step:638, action: 1, state: [59, 21]
# step:639, action: 0, state: [59, 22]
# step:640, action: 1, state: [59, 21]
# step:641, action: 0, state: [59, 22]
# step:642, action: 1, state: [59, 21]
# step:643, action: 0, state: [59, 22]
# step:644, action: 1, state: [59, 21]
# step:645, action: 0, state: [59, 22]
# step:646, action: 1, state: [59, 21]
# step:647, action: 0, state: [59, 22]
# step:648, action: 1, state: [59, 21]
# step:649, action: 0, state: [59, 22]
# step:650, action: 1, state: [59, 21]
# step:651, action: 0, state: [59, 22]
# step:652, action: 1, state: [59, 21]
# step:653, action: 0, state: [59, 22]
# step:654, action: 1, state: [59, 21]
# step:655, action: 0, state: [59, 22]
# step:656, action: 1, state: [59, 21]
# step:657, action: 0, state: [59, 22]
# step:658, action: 1, state: [59, 21]
# step:659, action: 0, state: [59, 22]
# step:660, action: 1, state: [59, 21]
# step:661, action: 0, state: [59, 22]
# step:662, action: 1, state: [59, 21]
# step:663, action: 0, state: [59, 22]
# step:664, action: 1, state: [59, 21]
# step:665, action: 0, state: [59, 22]
# step:666, action: 1, state: [59, 21]
# step:667, action: 0, state: [59, 22]
# step:668, action: 1, state: [59, 21]
# step:669, action: 0, state: [59, 22]
# step:670, action: 1, state: [59, 21]
# step:671, action: 0, state: [59, 22]
# step:672, action: 1, state: [59, 21]
# step:673, action: 0, state: [59, 22]
# step:674, action: 1, state: [59, 21]
# step:675, action: 0, state: [59, 22]
# step:676, action: 1, state: [59, 21]
# step:677, action: 0, state: [59, 22]
# step:678, action: 1, state: [59, 21]
# step:679, action: 0, state: [59, 22]
# step:680, action: 1, state: [59, 21]
# step:681, action: 0, state: [59, 22]
# step:682, action: 1, state: [59, 21]
# step:683, action: 0, state: [59, 22]
# step:684, action: 1, state: [59, 21]
# step:685, action: 0, state: [59, 22]
# step:686, action: 1, state: [59, 21]
# step:687, action: 0, state: [59, 22]
# step:688, action: 1, state: [59, 21]
# step:689, action: 0, state: [59, 22]
# step:690, action: 1, state: [59, 21]
# step:691, action: 0, state: [59, 22]
# step:692, action: 1, state: [59, 21]
# step:693, action: 0, state: [59, 22]
# step:694, action: 1, state: [59, 21]
# step:695, action: 0, state: [59, 22]
# step:696, action: 1, state: [59, 21]
# step:697, action: 0, state: [59, 22]
# step:698, action: 1, state: [59, 21]
# step:699, action: 0, state: [59, 22]
# step:700, action: 1, state: [59, 21]
# step:701, action: 0, state: [59, 22]
# step:702, action: 1, state: [59, 21]
# step:703, action: 0, state: [59, 22]
# step:704, action: 1, state: [59, 21]
# step:705, action: 0, state: [59, 22]
# step:706, action: 1, state: [59, 21]
# step:707, action: 0, state: [59, 22]
# step:708, action: 1, state: [59, 21]
# step:709, action: 0, state: [59, 22]
# step:710, action: 1, state: [59, 21]
# step:711, action: 0, state: [59, 22]
# step:712, action: 1, state: [59, 21]
# step:713, action: 0, state: [59, 22]
# step:714, action: 1, state: [59, 21]
# step:715, action: 0, state: [59, 22]
# step:716, action: 1, state: [59, 21]
# step:717, action: 0, state: [59, 22]
# step:718, action: 1, state: [59, 21]
# step:719, action: 0, state: [59, 22]
# step:720, action: 1, state: [59, 21]
# step:721, action: 0, state: [59, 22]
# step:722, action: 1, state: [59, 21]
# step:723, action: 0, state: [59, 22]
# step:724, action: 1, state: [59, 21]
# step:725, action: 0, state: [59, 22]
# step:726, action: 1, state: [59, 21]
# step:727, action: 0, state: [59, 22]
# step:728, action: 1, state: [59, 21]
# step:729, action: 0, state: [59, 22]
# step:730, action: 1, state: [59, 21]
# step:731, action: 0, state: [59, 22]
# step:732, action: 1, state: [59, 21]
# step:733, action: 0, state: [59, 22]
# step:734, action: 1, state: [59, 21]
# step:735, action: 0, state: [59, 22]
# step:736, action: 1, state: [59, 21]
# step:737, action: 0, state: [59, 22]
# step:738, action: 1, state: [59, 21]
# step:739, action: 0, state: [59, 22]
# step:740, action: 1, state: [59, 21]
# step:741, action: 0, state: [59, 22]
# step:742, action: 1, state: [59, 21]
# step:743, action: 0, state: [59, 22]
# step:744, action: 1, state: [59, 21]
# step:745, action: 0, state: [59, 22]
# step:746, action: 1, state: [59, 21]
# step:747, action: 0, state: [59, 22]
# step:748, action: 1, state: [59, 21]
# step:749, action: 0, state: [59, 22]
# step:750, action: 1, state: [59, 21]
# step:751, action: 0, state: [59, 22]
# step:752, action: 1, state: [59, 21]
# step:753, action: 0, state: [59, 22]
# step:754, action: 1, state: [59, 21]
# step:755, action: 0, state: [59, 22]
# step:756, action: 1, state: [59, 21]
# step:757, action: 0, state: [59, 22]
# step:758, action: 1, state: [59, 21]
# step:759, action: 0, state: [59, 22]
# step:760, action: 1, state: [59, 21]
# step:761, action: 0, state: [59, 22]
# step:762, action: 1, state: [59, 21]
# step:763, action: 0, state: [59, 22]
# step:764, action: 1, state: [59, 21]
# step:765, action: 0, state: [59, 22]
# step:766, action: 1, state: [59, 21]
# step:767, action: 0, state: [59, 22]
# step:768, action: 1, state: [59, 21]
# step:769, action: 0, state: [59, 22]
# step:770, action: 1, state: [59, 21]
# step:771, action: 0, state: [59, 22]
# step:772, action: 1, state: [59, 21]
# step:773, action: 0, state: [59, 22]
# step:774, action: 1, state: [59, 21]
# step:775, action: 0, state: [59, 22]
# step:776, action: 1, state: [59, 21]
# step:777, action: 0, state: [59, 22]
# step:778, action: 1, state: [59, 21]
# step:779, action: 0, state: [59, 22]
# step:780, action: 1, state: [59, 21]
# step:781, action: 0, state: [59, 22]
# step:782, action: 1, state: [59, 21]
# step:783, action: 0, state: [59, 22]
# step:784, action: 1, state: [59, 21]
# step:785, action: 0, state: [59, 22]
# step:786, action: 1, state: [59, 21]
# step:787, action: 0, state: [59, 22]
# step:788, action: 1, state: [59, 21]
# step:789, action: 0, state: [59, 22]
# step:790, action: 1, state: [59, 21]
# step:791, action: 0, state: [59, 22]
# step:792, action: 1, state: [59, 21]
# step:793, action: 0, state: [59, 22]
# step:794, action: 1, state: [59, 21]
# step:795, action: 0, state: [59, 22]
# step:796, action: 1, state: [59, 21]
# step:797, action: 0, state: [59, 22]
# step:798, action: 1, state: [59, 21]
# step:799, action: 0, state: [59, 22]
# step:800, action: 1, state: [59, 21]
# step:801, action: 0, state: [59, 22]
# step:802, action: 1, state: [59, 21]
# step:803, action: 0, state: [59, 22]
# step:804, action: 1, state: [59, 21]
# step:805, action: 0, state: [59, 22]
# step:806, action: 1, state: [59, 21]
# step:807, action: 0, state: [59, 22]
# step:808, action: 1, state: [59, 21]
# step:809, action: 0, state: [59, 22]
# step:810, action: 1, state: [59, 21]
# step:811, action: 0, state: [59, 22]
# step:812, action: 1, state: [59, 21]
# step:813, action: 0, state: [59, 22]
# step:814, action: 1, state: [59, 21]
# step:815, action: 0, state: [59, 22]
# step:816, action: 1, state: [59, 21]
# step:817, action: 0, state: [59, 22]
# step:818, action: 1, state: [59, 21]
# step:819, action: 0, state: [59, 22]
# step:820, action: 1, state: [59, 21]
# step:821, action: 0, state: [59, 22]
# step:822, action: 1, state: [59, 21]
# step:823, action: 0, state: [59, 22]
# step:824, action: 1, state: [59, 21]
# step:825, action: 0, state: [59, 22]
# step:826, action: 1, state: [59, 21]
# step:827, action: 0, state: [59, 22]
# step:828, action: 1, state: [59, 21]
# step:829, action: 0, state: [59, 22]
# step:830, action: 1, state: [59, 21]
# step:831, action: 0, state: [59, 22]
# step:832, action: 1, state: [59, 21]
# step:833, action: 0, state: [59, 22]
# step:834, action: 1, state: [59, 21]
# step:835, action: 0, state: [59, 22]
# step:836, action: 1, state: [59, 21]
# step:837, action: 0, state: [59, 22]
# step:838, action: 1, state: [59, 21]
# step:839, action: 0, state: [59, 22]
# step:840, action: 1, state: [59, 21]
# step:841, action: 0, state: [59, 22]
# step:842, action: 1, state: [59, 21]
# step:843, action: 0, state: [59, 22]
# step:844, action: 1, state: [59, 21]
# step:845, action: 0, state: [59, 22]
# step:846, action: 1, state: [59, 21]
# step:847, action: 0, state: [59, 22]
# step:848, action: 1, state: [59, 21]
# step:849, action: 0, state: [59, 22]
# step:850, action: 1, state: [59, 21]
# step:851, action: 0, state: [59, 22]
# step:852, action: 1, state: [59, 21]
# step:853, action: 0, state: [59, 22]
# step:854, action: 1, state: [59, 21]
# step:855, action: 0, state: [59, 22]
# step:856, action: 1, state: [59, 21]
# step:857, action: 0, state: [59, 22]
# step:858, action: 1, state: [59, 21]
# step:859, action: 0, state: [59, 22]
# step:860, action: 1, state: [59, 21]
# step:861, action: 0, state: [59, 22]
# step:862, action: 1, state: [59, 21]
# step:863, action: 0, state: [59, 22]
# step:864, action: 1, state: [59, 21]
# step:865, action: 0, state: [59, 22]
# step:866, action: 1, state: [59, 21]
# step:867, action: 0, state: [59, 22]
# step:868, action: 1, state: [59, 21]
# step:869, action: 0, state: [59, 22]
# step:870, action: 1, state: [59, 21]
# step:871, action: 0, state: [59, 22]
# step:872, action: 1, state: [59, 21]
# step:873, action: 0, state: [59, 22]
# step:874, action: 1, state: [59, 21]
# step:875, action: 0, state: [59, 22]
# step:876, action: 1, state: [59, 21]
# step:877, action: 0, state: [59, 22]
# step:878, action: 1, state: [59, 21]
# step:879, action: 0, state: [59, 22]
# step:880, action: 1, state: [59, 21]
# step:881, action: 0, state: [59, 22]
# step:882, action: 1, state: [59, 21]
# step:883, action: 0, state: [59, 22]
# step:884, action: 1, state: [59, 21]
# step:885, action: 0, state: [59, 22]
# step:886, action: 1, state: [59, 21]
# step:887, action: 0, state: [59, 22]
# step:888, action: 1, state: [59, 21]
# step:889, action: 0, state: [59, 22]
# step:890, action: 1, state: [59, 21]
# step:891, action: 0, state: [59, 22]
# step:892, action: 1, state: [59, 21]
# step:893, action: 0, state: [59, 22]
# step:894, action: 1, state: [59, 21]
# step:895, action: 0, state: [59, 22]
# step:896, action: 1, state: [59, 21]
# step:897, action: 0, state: [59, 22]
# step:898, action: 1, state: [59, 21]
# step:899, action: 0, state: [59, 22]
# step:900, action: 1, state: [59, 21]
# step:901, action: 0, state: [59, 22]
# step:902, action: 1, state: [59, 21]
# step:903, action: 0, state: [59, 22]
# step:904, action: 1, state: [59, 21]
# step:905, action: 0, state: [59, 22]
# step:906, action: 1, state: [59, 21]
# step:907, action: 0, state: [59, 22]
# step:908, action: 1, state: [59, 21]
# step:909, action: 0, state: [59, 22]
# step:910, action: 1, state: [59, 21]
# step:911, action: 0, state: [59, 22]
# step:912, action: 1, state: [59, 21]
# step:913, action: 0, state: [59, 22]
# step:914, action: 1, state: [59, 21]
# step:915, action: 0, state: [59, 22]
# step:916, action: 1, state: [59, 21]
# step:917, action: 0, state: [59, 22]
# step:918, action: 1, state: [59, 21]
# step:919, action: 0, state: [59, 22]
# step:920, action: 1, state: [59, 21]
# step:921, action: 0, state: [59, 22]
# step:922, action: 1, state: [59, 21]
# step:923, action: 0, state: [59, 22]
# step:924, action: 1, state: [59, 21]
# step:925, action: 0, state: [59, 22]
# step:926, action: 1, state: [59, 21]
# step:927, action: 0, state: [59, 22]
# step:928, action: 1, state: [59, 21]
# step:929, action: 0, state: [59, 22]
# step:930, action: 1, state: [59, 21]
# step:931, action: 0, state: [59, 22]
# step:932, action: 1, state: [59, 21]
# step:933, action: 0, state: [59, 22]
# step:934, action: 1, state: [59, 21]
# step:935, action: 0, state: [59, 22]
# step:936, action: 1, state: [59, 21]
# step:937, action: 0, state: [59, 22]
# step:938, action: 1, state: [59, 21]
# step:939, action: 0, state: [59, 22]
# step:940, action: 1, state: [59, 21]
# step:941, action: 0, state: [59, 22]
# step:942, action: 1, state: [59, 21]
# step:943, action: 0, state: [59, 22]
# step:944, action: 1, state: [59, 21]
# step:945, action: 0, state: [59, 22]
# step:946, action: 1, state: [59, 21]
# step:947, action: 0, state: [59, 22]
# step:948, action: 1, state: [59, 21]
# step:949, action: 0, state: [59, 22]
# step:950, action: 1, state: [59, 21]
# step:951, action: 0, state: [59, 22]
# step:952, action: 1, state: [59, 21]
# step:953, action: 0, state: [59, 22]
# step:954, action: 1, state: [59, 21]
# step:955, action: 0, state: [59, 22]
# step:956, action: 1, state: [59, 21]
# step:957, action: 0, state: [59, 22]
# step:958, action: 1, state: [59, 21]
# step:959, action: 0, state: [59, 22]
# step:960, action: 1, state: [59, 21]
# step:961, action: 0, state: [59, 22]
# step:962, action: 1, state: [59, 21]
# step:963, action: 0, state: [59, 22]
# step:964, action: 1, state: [59, 21]
# step:965, action: 0, state: [59, 22]
# step:966, action: 1, state: [59, 21]
# step:967, action: 0, state: [59, 22]
# step:968, action: 1, state: [59, 21]
# step:969, action: 0, state: [59, 22]
# step:970, action: 1, state: [59, 21]
# step:971, action: 0, state: [59, 22]
# step:972, action: 1, state: [59, 21]
# step:973, action: 0, state: [59, 22]
# step:974, action: 1, state: [59, 21]
# step:975, action: 0, state: [59, 22]
# step:976, action: 1, state: [59, 21]
# step:977, action: 0, state: [59, 22]
# step:978, action: 1, state: [59, 21]
# step:979, action: 0, state: [59, 22]
# step:980, action: 1, state: [59, 21]
# step:981, action: 0, state: [59, 22]
# step:982, action: 1, state: [59, 21]
# step:983, action: 0, state: [59, 22]
# step:984, action: 1, state: [59, 21]
# step:985, action: 0, state: [59, 22]
# step:986, action: 1, state: [59, 21]
# step:987, action: 0, state: [59, 22]
# step:988, action: 1, state: [59, 21]
# step:989, action: 0, state: [59, 22]
# step:990, action: 1, state: [59, 21]
# step:991, action: 0, state: [59, 22]
# step:992, action: 1, state: [59, 21]
# step:993, action: 0, state: [59, 22]
# step:994, action: 1, state: [59, 21]
# step:995, action: 0, state: [59, 22]
# step:996, action: 1, state: [59, 21]
# step:997, action: 0, state: [59, 22]
# step:998, action: 1, state: [59, 21]
# step:999, action: 0, state: [59, 22]
# step:1000, action: 1, state: [59, 21]
# step:1001, action: 0, state: [59, 22]
# fail
# [29, 1]
# 100%|██████████| 400/400 [10:21<00:00,  1.55s/it]
# start_state:[63, 44]
# step:1, action: 0, state: [63, 44]
# step:2, action: 0, state: [63, 43]
# step:3, action: 0, state: [63, 42]
# step:4, action: 0, state: [63, 41]
# step:5, action: 0, state: [63, 40]
# step:6, action: 0, state: [63, 39]
# step:7, action: 0, state: [63, 38]
# step:8, action: 0, state: [63, 37]
# step:9, action: 0, state: [63, 36]
# step:10, action: 0, state: [63, 35]
# step:11, action: 0, state: [63, 34]
# step:12, action: 0, state: [63, 33]
# step:13, action: 0, state: [63, 32]
# step:14, action: 0, state: [63, 31]
# step:15, action: 0, state: [63, 30]
# step:16, action: 0, state: [63, 29]
# step:17, action: 0, state: [63, 28]
# step:18, action: 3, state: [63, 27]
# step:19, action: 3, state: [62, 27]
# step:20, action: 1, state: [61, 27]
# step:21, action: 1, state: [61, 28]
# step:22, action: 1, state: [61, 29]
# step:23, action: 1, state: [61, 30]
# step:24, action: 3, state: [61, 31]
# step:25, action: 3, state: [60, 31]
# step:26, action: 3, state: [59, 31]
# step:27, action: 3, state: [58, 31]
# step:28, action: 0, state: [57, 31]
# step:29, action: 0, state: [57, 30]
# step:30, action: 0, state: [57, 29]
# step:31, action: 0, state: [57, 28]
# step:32, action: 0, state: [57, 27]
# step:33, action: 0, state: [57, 26]
# step:34, action: 3, state: [57, 25]
# step:35, action: 3, state: [56, 25]
# step:36, action: 1, state: [55, 25]
# step:37, action: 1, state: [55, 26]
# step:38, action: 1, state: [55, 27]
# step:39, action: 1, state: [55, 28]
# step:40, action: 3, state: [55, 29]
# step:41, action: 3, state: [54, 29]
# step:42, action: 1, state: [53, 29]
# step:43, action: 1, state: [53, 30]
# step:44, action: 3, state: [53, 31]
# step:45, action: 3, state: [52, 31]
# step:46, action: 0, state: [51, 31]
# step:47, action: 0, state: [51, 30]
# step:48, action: 3, state: [51, 29]
# step:49, action: 3, state: [50, 29]
# step:50, action: 0, state: [49, 29]
# step:51, action: 0, state: [49, 28]
# step:52, action: 0, state: [49, 27]
# step:53, action: 0, state: [49, 26]
# step:54, action: 0, state: [49, 25]
# step:55, action: 0, state: [49, 24]
# step:56, action: 3, state: [49, 23]
# step:57, action: 3, state: [48, 23]
# step:58, action: 0, state: [47, 23]
# step:59, action: 0, state: [47, 22]
# step:60, action: 0, state: [47, 21]
# step:61, action: 0, state: [47, 20]
# step:62, action: 0, state: [47, 19]
# step:63, action: 0, state: [47, 18]
# step:64, action: 2, state: [47, 17]
# step:65, action: 2, state: [48, 17]
# step:66, action: 1, state: [49, 17]
# step:67, action: 1, state: [49, 18]
# step:68, action: 1, state: [49, 19]
# step:69, action: 1, state: [49, 20]
# step:70, action: 2, state: [49, 21]
# step:71, action: 2, state: [50, 21]
# step:72, action: 2, state: [51, 21]
# step:73, action: 2, state: [52, 21]
# step:74, action: 1, state: [53, 21]
# step:75, action: 1, state: [53, 22]
# step:76, action: 2, state: [53, 23]
# step:77, action: 2, state: [54, 23]
# step:78, action: 2, state: [55, 23]
# step:79, action: 2, state: [56, 23]
# step:80, action: 0, state: [57, 23]
# step:81, action: 0, state: [57, 22]
# step:82, action: 3, state: [57, 21]
# step:83, action: 3, state: [56, 21]
# step:84, action: 0, state: [55, 21]
# step:85, action: 0, state: [55, 20]
# step:86, action: 0, state: [55, 19]
# step:87, action: 0, state: [55, 18]
# step:88, action: 0, state: [55, 17]
# step:89, action: 0, state: [55, 16]
# step:90, action: 0, state: [55, 15]
# step:91, action: 0, state: [55, 14]
# step:92, action: 0, state: [55, 13]
# step:93, action: 0, state: [55, 12]
# step:94, action: 3, state: [55, 11]
# step:95, action: 3, state: [54, 11]
# step:96, action: 3, state: [53, 11]
# step:97, action: 3, state: [52, 11]
# step:98, action: 1, state: [51, 11]
# step:99, action: 1, state: [51, 12]
# step:100, action: 1, state: [51, 13]
# step:101, action: 1, state: [51, 14]
# step:102, action: 3, state: [51, 15]
# step:103, action: 3, state: [50, 15]
# step:104, action: 0, state: [49, 15]
# step:105, action: 0, state: [49, 14]
# step:106, action: 0, state: [49, 13]
# step:107, action: 0, state: [49, 12]
# step:108, action: 0, state: [49, 11]
# step:109, action: 0, state: [49, 10]
# step:110, action: 0, state: [49, 9]
# step:111, action: 0, state: [49, 8]
# step:112, action: 0, state: [49, 7]
# step:113, action: 0, state: [49, 6]
# step:114, action: 3, state: [49, 5]
# step:115, action: 3, state: [48, 5]
# step:116, action: 1, state: [47, 5]
# step:117, action: 1, state: [47, 6]
# step:118, action: 3, state: [47, 7]
# step:119, action: 3, state: [46, 7]
# step:120, action: 1, state: [45, 7]
# step:121, action: 1, state: [45, 8]
# step:122, action: 1, state: [45, 9]
# step:123, action: 1, state: [45, 10]
# step:124, action: 3, state: [45, 11]
# step:125, action: 3, state: [44, 11]
# step:126, action: 0, state: [43, 11]
# step:127, action: 0, state: [43, 10]
# step:128, action: 0, state: [43, 9]
# step:129, action: 0, state: [43, 8]
# step:130, action: 0, state: [43, 7]
# step:131, action: 0, state: [43, 6]
# step:132, action: 3, state: [43, 5]
# step:133, action: 3, state: [42, 5]
# step:134, action: 0, state: [41, 5]
# step:135, action: 0, state: [41, 4]
# step:136, action: 2, state: [41, 3]
# step:137, action: 2, state: [42, 3]
# step:138, action: 0, state: [43, 3]
# step:139, action: 0, state: [43, 2]
# step:140, action: 2, state: [43, 1]
# step:141, action: 2, state: [44, 1]
# step:142, action: 1, state: [45, 1]
# step:143, action: 1, state: [45, 2]
# step:144, action: 2, state: [45, 3]
# step:145, action: 2, state: [46, 3]
# step:146, action: 0, state: [47, 3]
# step:147, action: 0, state: [47, 2]
# step:148, action: 2, state: [47, 1]
# step:149, action: 2, state: [48, 1]
# step:150, action: 2, state: [49, 1]
# step:151, action: 2, state: [50, 1]
# step:152, action: 1, state: [51, 1]
# step:153, action: 1, state: [51, 2]
# step:154, action: 1, state: [51, 3]
# step:155, action: 1, state: [51, 4]
# step:156, action: 1, state: [51, 5]
# step:157, action: 1, state: [51, 6]
# step:158, action: 2, state: [51, 7]
# step:159, action: 2, state: [52, 7]
# step:160, action: 2, state: [53, 7]
# step:161, action: 2, state: [54, 7]
# step:162, action: 2, state: [55, 7]
# step:163, action: 3, state: [56, 7]
# step:164, action: 2, state: [55, 7]
# step:165, action: 3, state: [56, 7]
# step:166, action: 2, state: [55, 7]
# step:167, action: 3, state: [56, 7]
# step:168, action: 2, state: [55, 7]
# step:169, action: 3, state: [56, 7]
# step:170, action: 2, state: [55, 7]
# step:171, action: 3, state: [56, 7]
# step:172, action: 2, state: [55, 7]
# step:173, action: 3, state: [56, 7]
# step:174, action: 2, state: [55, 7]
# step:175, action: 3, state: [56, 7]
# step:176, action: 2, state: [55, 7]
# step:177, action: 3, state: [56, 7]
# step:178, action: 2, state: [55, 7]
# step:179, action: 3, state: [56, 7]
# step:180, action: 2, state: [55, 7]
# step:181, action: 3, state: [56, 7]
# step:182, action: 2, state: [55, 7]
# step:183, action: 3, state: [56, 7]
# step:184, action: 2, state: [55, 7]
# step:185, action: 3, state: [56, 7]
# step:186, action: 2, state: [55, 7]
# step:187, action: 3, state: [56, 7]
# step:188, action: 2, state: [55, 7]
# step:189, action: 3, state: [56, 7]
# step:190, action: 2, state: [55, 7]
# step:191, action: 3, state: [56, 7]
# step:192, action: 2, state: [55, 7]
# step:193, action: 3, state: [56, 7]
# step:194, action: 2, state: [55, 7]
# step:195, action: 3, state: [56, 7]
# step:196, action: 2, state: [55, 7]
# step:197, action: 3, state: [56, 7]
# step:198, action: 2, state: [55, 7]
# step:199, action: 3, state: [56, 7]
# step:200, action: 2, state: [55, 7]
# step:201, action: 3, state: [56, 7]
# step:202, action: 2, state: [55, 7]
# step:203, action: 3, state: [56, 7]
# step:204, action: 2, state: [55, 7]
# step:205, action: 3, state: [56, 7]
# step:206, action: 2, state: [55, 7]
# step:207, action: 3, state: [56, 7]
# step:208, action: 2, state: [55, 7]
# step:209, action: 3, state: [56, 7]
# step:210, action: 2, state: [55, 7]
# step:211, action: 3, state: [56, 7]
# step:212, action: 2, state: [55, 7]
# step:213, action: 3, state: [56, 7]
# step:214, action: 2, state: [55, 7]
# step:215, action: 3, state: [56, 7]
# step:216, action: 2, state: [55, 7]
# step:217, action: 3, state: [56, 7]
# step:218, action: 2, state: [55, 7]
# step:219, action: 3, state: [56, 7]
# step:220, action: 2, state: [55, 7]
# step:221, action: 3, state: [56, 7]
# step:222, action: 2, state: [55, 7]
# step:223, action: 3, state: [56, 7]
# step:224, action: 2, state: [55, 7]
# step:225, action: 3, state: [56, 7]
# step:226, action: 2, state: [55, 7]
# step:227, action: 3, state: [56, 7]
# step:228, action: 2, state: [55, 7]
# step:229, action: 3, state: [56, 7]
# step:230, action: 2, state: [55, 7]
# step:231, action: 3, state: [56, 7]
# step:232, action: 2, state: [55, 7]
# step:233, action: 3, state: [56, 7]
# step:234, action: 2, state: [55, 7]
# step:235, action: 3, state: [56, 7]
# step:236, action: 2, state: [55, 7]
# step:237, action: 3, state: [56, 7]
# step:238, action: 2, state: [55, 7]
# step:239, action: 3, state: [56, 7]
# step:240, action: 2, state: [55, 7]
# step:241, action: 3, state: [56, 7]
# step:242, action: 2, state: [55, 7]
# step:243, action: 3, state: [56, 7]
# step:244, action: 2, state: [55, 7]
# step:245, action: 3, state: [56, 7]
# step:246, action: 2, state: [55, 7]
# step:247, action: 3, state: [56, 7]
# step:248, action: 2, state: [55, 7]
# step:249, action: 3, state: [56, 7]
# step:250, action: 2, state: [55, 7]
# step:251, action: 3, state: [56, 7]
# step:252, action: 2, state: [55, 7]
# step:253, action: 3, state: [56, 7]
# step:254, action: 2, state: [55, 7]
# step:255, action: 3, state: [56, 7]
# step:256, action: 2, state: [55, 7]
# step:257, action: 3, state: [56, 7]
# step:258, action: 2, state: [55, 7]
# step:259, action: 3, state: [56, 7]
# step:260, action: 2, state: [55, 7]
# step:261, action: 3, state: [56, 7]
# step:262, action: 2, state: [55, 7]
# step:263, action: 3, state: [56, 7]
# step:264, action: 2, state: [55, 7]
# step:265, action: 3, state: [56, 7]
# step:266, action: 2, state: [55, 7]
# step:267, action: 3, state: [56, 7]
# step:268, action: 2, state: [55, 7]
# step:269, action: 3, state: [56, 7]
# step:270, action: 2, state: [55, 7]
# step:271, action: 3, state: [56, 7]
# step:272, action: 2, state: [55, 7]
# step:273, action: 3, state: [56, 7]
# step:274, action: 2, state: [55, 7]
# step:275, action: 3, state: [56, 7]
# step:276, action: 2, state: [55, 7]
# step:277, action: 3, state: [56, 7]
# step:278, action: 2, state: [55, 7]
# step:279, action: 3, state: [56, 7]
# step:280, action: 2, state: [55, 7]
# step:281, action: 3, state: [56, 7]
# step:282, action: 2, state: [55, 7]
# step:283, action: 3, state: [56, 7]
# step:284, action: 2, state: [55, 7]
# step:285, action: 3, state: [56, 7]
# step:286, action: 2, state: [55, 7]
# step:287, action: 3, state: [56, 7]
# step:288, action: 2, state: [55, 7]
# step:289, action: 3, state: [56, 7]
# step:290, action: 2, state: [55, 7]
# step:291, action: 3, state: [56, 7]
# step:292, action: 2, state: [55, 7]
# step:293, action: 3, state: [56, 7]
# step:294, action: 2, state: [55, 7]
# step:295, action: 3, state: [56, 7]
# step:296, action: 2, state: [55, 7]
# step:297, action: 3, state: [56, 7]
# step:298, action: 2, state: [55, 7]
# step:299, action: 3, state: [56, 7]
# step:300, action: 2, state: [55, 7]
# step:301, action: 3, state: [56, 7]
# step:302, action: 2, state: [55, 7]
# step:303, action: 3, state: [56, 7]
# step:304, action: 2, state: [55, 7]
# ...
# step:558, action: 2, state: [55, 7]
# step:559, action: 3, state: [56, 7]
# step:560, action: 2, state: [55, 7]
# step:561, action: 3, state: [56, 7]
# step:562, action: 2, state: [55, 7]
# step:563, action: 3, state: [56, 7]
# step:564, action: 2, state: [55, 7]
# step:565, action: 3, state: [56, 7]
# step:566, action: 2, state: [55, 7]
# step:567, action: 3, state: [56, 7]
# step:568, action: 2, state: [55, 7]
# step:569, action: 3, state: [56, 7]
# step:570, action: 2, state: [55, 7]
# step:571, action: 3, state: [56, 7]
# step:572, action: 2, state: [55, 7]
# step:573, action: 3, state: [56, 7]
# step:574, action: 2, state: [55, 7]
# step:575, action: 3, state: [56, 7]
# step:576, action: 2, state: [55, 7]
# step:577, action: 3, state: [56, 7]
# step:578, action: 2, state: [55, 7]
# step:579, action: 3, state: [56, 7]
# step:580, action: 2, state: [55, 7]
# step:581, action: 3, state: [56, 7]
# step:582, action: 2, state: [55, 7]
# step:583, action: 3, state: [56, 7]
# step:584, action: 2, state: [55, 7]
# step:585, action: 3, state: [56, 7]
# step:586, action: 2, state: [55, 7]
# step:587, action: 3, state: [56, 7]
# step:588, action: 2, state: [55, 7]
# step:589, action: 3, state: [56, 7]
# step:590, action: 2, state: [55, 7]
# step:591, action: 3, state: [56, 7]
# step:592, action: 2, state: [55, 7]
# step:593, action: 3, state: [56, 7]
# step:594, action: 2, state: [55, 7]
# step:595, action: 3, state: [56, 7]
# step:596, action: 2, state: [55, 7]
# step:597, action: 3, state: [56, 7]
# step:598, action: 2, state: [55, 7]
# step:599, action: 3, state: [56, 7]
# step:600, action: 2, state: [55, 7]
# step:601, action: 3, state: [56, 7]
# step:602, action: 2, state: [55, 7]
# step:603, action: 3, state: [56, 7]
# step:604, action: 2, state: [55, 7]
# step:605, action: 3, state: [56, 7]
# step:606, action: 2, state: [55, 7]
# step:607, action: 3, state: [56, 7]
# step:608, action: 2, state: [55, 7]
# step:609, action: 3, state: [56, 7]
# step:610, action: 2, state: [55, 7]
# step:611, action: 3, state: [56, 7]
# step:612, action: 2, state: [55, 7]
# step:613, action: 3, state: [56, 7]
# step:614, action: 2, state: [55, 7]
# step:615, action: 3, state: [56, 7]
# step:616, action: 2, state: [55, 7]
# step:617, action: 3, state: [56, 7]
# step:618, action: 2, state: [55, 7]
# step:619, action: 3, state: [56, 7]
# step:620, action: 2, state: [55, 7]
# step:621, action: 3, state: [56, 7]
# step:622, action: 2, state: [55, 7]
# step:623, action: 3, state: [56, 7]
# step:624, action: 2, state: [55, 7]
# step:625, action: 3, state: [56, 7]
# step:626, action: 2, state: [55, 7]
# step:627, action: 3, state: [56, 7]
# step:628, action: 2, state: [55, 7]
# step:629, action: 3, state: [56, 7]
# step:630, action: 2, state: [55, 7]
# step:631, action: 3, state: [56, 7]
# step:632, action: 2, state: [55, 7]
# step:633, action: 3, state: [56, 7]
# step:634, action: 2, state: [55, 7]
# step:635, action: 3, state: [56, 7]
# step:636, action: 2, state: [55, 7]
# step:637, action: 3, state: [56, 7]
# step:638, action: 2, state: [55, 7]
# step:639, action: 3, state: [56, 7]
# step:640, action: 2, state: [55, 7]
# step:641, action: 3, state: [56, 7]
# step:642, action: 2, state: [55, 7]
# step:643, action: 3, state: [56, 7]
# step:644, action: 2, state: [55, 7]
# step:645, action: 3, state: [56, 7]
# step:646, action: 2, state: [55, 7]
# step:647, action: 3, state: [56, 7]
# step:648, action: 2, state: [55, 7]
# step:649, action: 3, state: [56, 7]
# step:650, action: 2, state: [55, 7]
# step:651, action: 3, state: [56, 7]
# step:652, action: 2, state: [55, 7]
# step:653, action: 3, state: [56, 7]
# step:654, action: 2, state: [55, 7]
# step:655, action: 3, state: [56, 7]
# step:656, action: 2, state: [55, 7]
# step:657, action: 3, state: [56, 7]
# step:658, action: 2, state: [55, 7]
# step:659, action: 3, state: [56, 7]
# step:660, action: 2, state: [55, 7]
# step:661, action: 3, state: [56, 7]
# step:662, action: 2, state: [55, 7]
# step:663, action: 3, state: [56, 7]
# step:664, action: 2, state: [55, 7]
# step:665, action: 3, state: [56, 7]
# step:666, action: 2, state: [55, 7]
# step:667, action: 3, state: [56, 7]
# step:668, action: 2, state: [55, 7]
# step:669, action: 3, state: [56, 7]
# step:670, action: 2, state: [55, 7]
# step:671, action: 3, state: [56, 7]
# step:672, action: 2, state: [55, 7]
# step:673, action: 3, state: [56, 7]
# step:674, action: 2, state: [55, 7]
# step:675, action: 3, state: [56, 7]
# step:676, action: 2, state: [55, 7]
# step:677, action: 3, state: [56, 7]
# step:678, action: 2, state: [55, 7]
# step:679, action: 3, state: [56, 7]
# step:680, action: 2, state: [55, 7]
# step:681, action: 3, state: [56, 7]
# step:682, action: 2, state: [55, 7]
# step:683, action: 3, state: [56, 7]
# step:684, action: 2, state: [55, 7]
# step:685, action: 3, state: [56, 7]
# step:686, action: 2, state: [55, 7]
# step:687, action: 3, state: [56, 7]
# step:688, action: 2, state: [55, 7]
# step:689, action: 3, state: [56, 7]
# step:690, action: 2, state: [55, 7]
# step:691, action: 3, state: [56, 7]
# step:692, action: 2, state: [55, 7]
# step:693, action: 3, state: [56, 7]
# step:694, action: 2, state: [55, 7]
# step:695, action: 3, state: [56, 7]
# step:696, action: 2, state: [55, 7]
# step:697, action: 3, state: [56, 7]
# step:698, action: 2, state: [55, 7]
# step:699, action: 3, state: [56, 7]
# step:700, action: 2, state: [55, 7]
# step:701, action: 3, state: [56, 7]
# step:702, action: 2, state: [55, 7]
# step:703, action: 3, state: [56, 7]
# step:704, action: 2, state: [55, 7]
# step:705, action: 3, state: [56, 7]
# step:706, action: 2, state: [55, 7]
# step:707, action: 3, state: [56, 7]
# step:708, action: 2, state: [55, 7]
# step:709, action: 3, state: [56, 7]
# step:710, action: 2, state: [55, 7]
# step:711, action: 3, state: [56, 7]
# step:712, action: 2, state: [55, 7]
# step:713, action: 3, state: [56, 7]
# step:714, action: 2, state: [55, 7]
# step:715, action: 3, state: [56, 7]
# step:716, action: 2, state: [55, 7]
# step:717, action: 3, state: [56, 7]
# step:718, action: 2, state: [55, 7]
# step:719, action: 3, state: [56, 7]
# step:720, action: 2, state: [55, 7]
# step:721, action: 3, state: [56, 7]
# step:722, action: 2, state: [55, 7]
# step:723, action: 3, state: [56, 7]
# step:724, action: 2, state: [55, 7]
# step:725, action: 3, state: [56, 7]
# step:726, action: 2, state: [55, 7]
# step:727, action: 3, state: [56, 7]
# step:728, action: 2, state: [55, 7]
# step:729, action: 3, state: [56, 7]
# step:730, action: 2, state: [55, 7]
# step:731, action: 3, state: [56, 7]
# step:732, action: 2, state: [55, 7]
# step:733, action: 3, state: [56, 7]
# step:734, action: 2, state: [55, 7]
# step:735, action: 3, state: [56, 7]
# step:736, action: 2, state: [55, 7]
# step:737, action: 3, state: [56, 7]
# step:738, action: 2, state: [55, 7]
# step:739, action: 3, state: [56, 7]
# step:740, action: 2, state: [55, 7]
# step:741, action: 3, state: [56, 7]
# step:742, action: 2, state: [55, 7]
# step:743, action: 3, state: [56, 7]
# step:744, action: 2, state: [55, 7]
# step:745, action: 3, state: [56, 7]
# step:746, action: 2, state: [55, 7]
# step:747, action: 3, state: [56, 7]
# step:748, action: 2, state: [55, 7]
# step:749, action: 3, state: [56, 7]
# step:750, action: 2, state: [55, 7]
# step:751, action: 3, state: [56, 7]
# step:752, action: 2, state: [55, 7]
# step:753, action: 3, state: [56, 7]
# step:754, action: 2, state: [55, 7]
# step:755, action: 3, state: [56, 7]
# step:756, action: 2, state: [55, 7]
# step:757, action: 3, state: [56, 7]
# step:758, action: 2, state: [55, 7]
# step:759, action: 3, state: [56, 7]
# step:760, action: 2, state: [55, 7]
# step:761, action: 3, state: [56, 7]
# step:762, action: 2, state: [55, 7]
# step:763, action: 3, state: [56, 7]
# step:764, action: 2, state: [55, 7]
# step:765, action: 3, state: [56, 7]
# step:766, action: 2, state: [55, 7]
# step:767, action: 3, state: [56, 7]
# step:768, action: 2, state: [55, 7]
# step:769, action: 3, state: [56, 7]
# step:770, action: 2, state: [55, 7]
# step:771, action: 3, state: [56, 7]
# step:772, action: 2, state: [55, 7]
# step:773, action: 3, state: [56, 7]
# step:774, action: 2, state: [55, 7]
# step:775, action: 3, state: [56, 7]
# step:776, action: 2, state: [55, 7]
# step:777, action: 3, state: [56, 7]
# step:778, action: 2, state: [55, 7]
# step:779, action: 3, state: [56, 7]
# step:780, action: 2, state: [55, 7]
# step:781, action: 3, state: [56, 7]
# step:782, action: 2, state: [55, 7]
# step:783, action: 3, state: [56, 7]
# step:784, action: 2, state: [55, 7]
# step:785, action: 3, state: [56, 7]
# step:786, action: 2, state: [55, 7]
# step:787, action: 3, state: [56, 7]
# step:788, action: 2, state: [55, 7]
# step:789, action: 3, state: [56, 7]
# step:790, action: 2, state: [55, 7]
# step:791, action: 3, state: [56, 7]
# step:792, action: 2, state: [55, 7]
# step:793, action: 3, state: [56, 7]
# step:794, action: 2, state: [55, 7]
# step:795, action: 3, state: [56, 7]
# step:796, action: 2, state: [55, 7]
# step:797, action: 3, state: [56, 7]
# step:798, action: 2, state: [55, 7]
# step:799, action: 3, state: [56, 7]
# step:800, action: 2, state: [55, 7]
# step:801, action: 3, state: [56, 7]
# step:802, action: 2, state: [55, 7]
# step:803, action: 3, state: [56, 7]
# step:804, action: 2, state: [55, 7]
# step:805, action: 3, state: [56, 7]
# step:806, action: 2, state: [55, 7]
# step:807, action: 3, state: [56, 7]
# step:808, action: 2, state: [55, 7]
# step:809, action: 3, state: [56, 7]
# step:810, action: 2, state: [55, 7]
# step:811, action: 3, state: [56, 7]
# step:812, action: 2, state: [55, 7]
# step:813, action: 3, state: [56, 7]
# step:814, action: 2, state: [55, 7]
# step:815, action: 3, state: [56, 7]
# step:816, action: 2, state: [55, 7]
# step:817, action: 3, state: [56, 7]
# step:818, action: 2, state: [55, 7]
# step:819, action: 3, state: [56, 7]
# step:820, action: 2, state: [55, 7]
# step:821, action: 3, state: [56, 7]
# step:822, action: 2, state: [55, 7]
# step:823, action: 3, state: [56, 7]
# step:824, action: 2, state: [55, 7]
# step:825, action: 3, state: [56, 7]
# step:826, action: 2, state: [55, 7]
# step:827, action: 3, state: [56, 7]
# step:828, action: 2, state: [55, 7]
# step:829, action: 3, state: [56, 7]
# step:830, action: 2, state: [55, 7]
# step:831, action: 3, state: [56, 7]
# step:832, action: 2, state: [55, 7]
# step:833, action: 3, state: [56, 7]
# step:834, action: 2, state: [55, 7]
# step:835, action: 3, state: [56, 7]
# step:836, action: 2, state: [55, 7]
# step:837, action: 3, state: [56, 7]
# step:838, action: 2, state: [55, 7]
# step:839, action: 3, state: [56, 7]
# step:840, action: 2, state: [55, 7]
# step:841, action: 3, state: [56, 7]
# step:842, action: 2, state: [55, 7]
# step:843, action: 3, state: [56, 7]
# step:844, action: 2, state: [55, 7]
# step:845, action: 3, state: [56, 7]
# step:846, action: 2, state: [55, 7]
# step:847, action: 3, state: [56, 7]
# step:848, action: 2, state: [55, 7]
# step:849, action: 3, state: [56, 7]
# step:850, action: 2, state: [55, 7]
# step:851, action: 3, state: [56, 7]
# step:852, action: 2, state: [55, 7]
# step:853, action: 3, state: [56, 7]
# step:854, action: 2, state: [55, 7]
# step:855, action: 3, state: [56, 7]
# step:856, action: 2, state: [55, 7]
# step:857, action: 3, state: [56, 7]
# step:858, action: 2, state: [55, 7]
# step:859, action: 3, state: [56, 7]
# step:860, action: 2, state: [55, 7]
# step:861, action: 3, state: [56, 7]
# step:862, action: 2, state: [55, 7]
# step:863, action: 3, state: [56, 7]
# step:864, action: 2, state: [55, 7]
# step:865, action: 3, state: [56, 7]
# step:866, action: 2, state: [55, 7]
# step:867, action: 3, state: [56, 7]
# step:868, action: 2, state: [55, 7]
# step:869, action: 3, state: [56, 7]
# step:870, action: 2, state: [55, 7]
# step:871, action: 3, state: [56, 7]
# step:872, action: 2, state: [55, 7]
# step:873, action: 3, state: [56, 7]
# step:874, action: 2, state: [55, 7]
# step:875, action: 3, state: [56, 7]
# step:876, action: 2, state: [55, 7]
# step:877, action: 3, state: [56, 7]
# step:878, action: 2, state: [55, 7]
# step:879, action: 3, state: [56, 7]
# step:880, action: 2, state: [55, 7]
# step:881, action: 3, state: [56, 7]
# step:882, action: 2, state: [55, 7]
# step:883, action: 3, state: [56, 7]
# step:884, action: 2, state: [55, 7]
# step:885, action: 3, state: [56, 7]
# step:886, action: 2, state: [55, 7]
# step:887, action: 3, state: [56, 7]
# step:888, action: 2, state: [55, 7]
# step:889, action: 3, state: [56, 7]
# step:890, action: 2, state: [55, 7]
# step:891, action: 3, state: [56, 7]
# step:892, action: 2, state: [55, 7]
# step:893, action: 3, state: [56, 7]
# step:894, action: 2, state: [55, 7]
# step:895, action: 3, state: [56, 7]
# step:896, action: 2, state: [55, 7]
# step:897, action: 3, state: [56, 7]
# step:898, action: 2, state: [55, 7]
# step:899, action: 3, state: [56, 7]
# step:900, action: 2, state: [55, 7]
# step:901, action: 3, state: [56, 7]
# step:902, action: 2, state: [55, 7]
# step:903, action: 3, state: [56, 7]
# step:904, action: 2, state: [55, 7]
# step:905, action: 3, state: [56, 7]
# step:906, action: 2, state: [55, 7]
# step:907, action: 3, state: [56, 7]
# step:908, action: 2, state: [55, 7]
# step:909, action: 3, state: [56, 7]
# step:910, action: 2, state: [55, 7]
# step:911, action: 3, state: [56, 7]
# step:912, action: 2, state: [55, 7]
# step:913, action: 3, state: [56, 7]
# step:914, action: 2, state: [55, 7]
# step:915, action: 3, state: [56, 7]
# step:916, action: 2, state: [55, 7]
# step:917, action: 3, state: [56, 7]
# step:918, action: 2, state: [55, 7]
# step:919, action: 3, state: [56, 7]
# step:920, action: 2, state: [55, 7]
# step:921, action: 3, state: [56, 7]
# step:922, action: 2, state: [55, 7]
# step:923, action: 3, state: [56, 7]
# step:924, action: 2, state: [55, 7]
# step:925, action: 3, state: [56, 7]
# step:926, action: 2, state: [55, 7]
# step:927, action: 3, state: [56, 7]
# step:928, action: 2, state: [55, 7]
# step:929, action: 3, state: [56, 7]
# step:930, action: 2, state: [55, 7]
# step:931, action: 3, state: [56, 7]
# step:932, action: 2, state: [55, 7]
# step:933, action: 3, state: [56, 7]
# step:934, action: 2, state: [55, 7]
# step:935, action: 3, state: [56, 7]
# step:936, action: 2, state: [55, 7]
# step:937, action: 3, state: [56, 7]
# step:938, action: 2, state: [55, 7]
# step:939, action: 3, state: [56, 7]
# step:940, action: 2, state: [55, 7]
# step:941, action: 3, state: [56, 7]
# step:942, action: 2, state: [55, 7]
# step:943, action: 3, state: [56, 7]
# step:944, action: 2, state: [55, 7]
# step:945, action: 3, state: [56, 7]
# step:946, action: 2, state: [55, 7]
# step:947, action: 3, state: [56, 7]
# step:948, action: 2, state: [55, 7]
# step:949, action: 3, state: [56, 7]
# step:950, action: 2, state: [55, 7]
# step:951, action: 3, state: [56, 7]
# step:952, action: 2, state: [55, 7]
# step:953, action: 3, state: [56, 7]
# step:954, action: 2, state: [55, 7]
# step:955, action: 3, state: [56, 7]
# step:956, action: 2, state: [55, 7]
# step:957, action: 3, state: [56, 7]
# step:958, action: 2, state: [55, 7]
# step:959, action: 3, state: [56, 7]
# step:960, action: 2, state: [55, 7]
# step:961, action: 3, state: [56, 7]
# step:962, action: 2, state: [55, 7]
# step:963, action: 3, state: [56, 7]
# step:964, action: 2, state: [55, 7]
# step:965, action: 3, state: [56, 7]
# step:966, action: 2, state: [55, 7]
# step:967, action: 3, state: [56, 7]
# step:968, action: 2, state: [55, 7]
# step:969, action: 3, state: [56, 7]
# step:970, action: 2, state: [55, 7]
# step:971, action: 3, state: [56, 7]
# step:972, action: 2, state: [55, 7]
# step:973, action: 3, state: [56, 7]
# step:974, action: 2, state: [55, 7]
# step:975, action: 3, state: [56, 7]
# step:976, action: 2, state: [55, 7]
# step:977, action: 3, state: [56, 7]
# step:978, action: 2, state: [55, 7]
# step:979, action: 3, state: [56, 7]
# step:980, action: 2, state: [55, 7]
# step:981, action: 3, state: [56, 7]
# step:982, action: 2, state: [55, 7]
# step:983, action: 3, state: [56, 7]
# step:984, action: 2, state: [55, 7]
# step:985, action: 3, state: [56, 7]
# step:986, action: 2, state: [55, 7]
# step:987, action: 3, state: [56, 7]
# step:988, action: 2, state: [55, 7]
# step:989, action: 3, state: [56, 7]
# step:990, action: 2, state: [55, 7]
# step:991, action: 3, state: [56, 7]
# step:992, action: 2, state: [55, 7]
# step:993, action: 3, state: [56, 7]
# step:994, action: 2, state: [55, 7]
# step:995, action: 3, state: [56, 7]
# step:996, action: 2, state: [55, 7]
# step:997, action: 3, state: [56, 7]
# step:998, action: 2, state: [55, 7]
# step:999, action: 3, state: [56, 7]
# step:1000, action: 2, state: [55, 7]
# step:1001, action: 3, state: [56, 7]
# fail
